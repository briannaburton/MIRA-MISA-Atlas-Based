# %%
! mkdir ./registration-results/affine+bspline/1002

# %%
# %%bash
# export DYLD_LIBRARY_PATH=/Applications/elastix_macosx64_v4.8/lib:$DYLD_LIBRARY_PATH
#
# echo $DYLD_LIBRARY_PATH
# elastix -f 1000.nii.gz -m ./training-images/1002.nii.gz -out ./registration-results/affine+bspline/1002 -p par0000affine.txt -p par0000bspline.txt
# Out:
# /Applications/elastix_macosx64_v4.8/lib:
#
# elastix is started at Fri Nov  9 13:27:52 2018.
#
# which elastix:   elastix
# elastix runs at: Briannas-MacBook-Pro.local
#   Mac OS X 10.14 (x64), 18A391
#   with 16384 MB memory, and 2 cores @ 2700 MHz.
# -------------------------------------------------------------------------
#
# Running elastix with parameter file 0: "par0000affine.txt".
#
# Current time: Fri Nov  9 13:27:52 2018.
# Reading the elastix parameters from file ...
#
# Installing all components.
# InstallingComponents was successful.
#
# ERROR: OpenCL device: Intel(R) Iris(TM) Graphics 6100, does not support 'double' computations. Consider updating it.
# OpenCL processing is disabled.
# ELASTIX version: 4.800
# Command line options from ElastixBase:
# -f        1000.nii.gz
# -m        ./training-images/1002.nii.gz
# -fMask    unspecified, so no fixed mask used
# -mMask    unspecified, so no moving mask used
# -out      ./registration-results/affine+bspline/1002/
# ...
